# %% [markdown]
# # Project 1: SAT & ACT Data Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The new format of the SAT was released in Mar 2016, as part of the team working in the College Board, we have been tasked by the Board to look at increasing SAT participation rates across the various states.
# The Board noticed that lower SAT test participation rates in comparison to our competitor, the ACTs, has impacted our revenue.
#
# Hence, a good starting point would be to look at the current SAT participation rate in comparison to ACTs. As well as, the current demographics and what pain points they are facing.
#
# My problem statement is : How the College Board might work to increase the participation rate among high school students in taking SAT college entrance test in 3 states-Kansas, Minnesota & Massachusetts?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-&-Cleaning)
# - [Data Dictionary](#Data-Dictionary)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Data-Visualization)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 4 datasets included in the [`data`](./data/) folder for this project.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
#
# For SAT, We have the 2017 & 2018 mean participation rate and mean SAT scores for 2 subjects:Evidence-Based Reading and Writing, Math, and the mean Total Score by states.
#
# Each year's SAT data consists of 51 rows by 5 columns, each row represents an US state in relation to its individual columns.
#
#     - SAT Participation Rate
#     - Average Evidence-Based Reading and Writing Score
#     - Average Math Score
#     - Total Average Score
#
# For ACT, We have the 2017 to 2018 participation rate and mean ACT scores by states.
#
# In 2017 ACT data, there is the mean participation rate and the breakdown of mean scores by all 5 subjects: English, Math, Reading, Science and Compiste.
#
# However in 2018 ACT data, there is the mean participation rate and mean scores for 1 subject: Composite.
#
# Both 2 years ACT data has 52 rows, however US has 51 states only. We will further look at the data and do some necessary data examinations and cleaning before proceed on further analysis.
#
#     - ACT Participation Rate
#     - Average English Score
#     - Average Math Score
#     - Average Reading Score
#     - Average Science Score
#     - Average Composite Score
#
# Reference resource:
# * https://collegereadiness.collegeboard.org/sat/scores/understanding-scores/interpreting.
# * https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html.
# * https://reports.collegeboard.org/pdf/2017-total-group-sat-suite-assessments-annual-report.pdf
# * https://collegereadiness.collegeboard.org/sat
# * http://www.act.org/content/dam/act/unsecured/documents/cccr2017/CCCR_National_2017.pdf

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# We have done some search and compared SAT & ACT particiation, policies and exam structure changes in year 2017 & 2018.
#
# In 2018, there were 18 states that require ACT exam while 11 states require SAT exam. In the same year, SAT had surpassed rival ACT to reclaim it long-held position as the nations' most widely used college admission test. Nearly 2 million US students in the class of 2018 took the SAT during high school, compared with 1.91 million who took the ACT. This is the largest number of students in a graduating class to take the SAT.
#
# One possible reason for SAT's surge was College Board, which owns the SAT, pushed to expand its market share in recent years by revising the test and entering into deals with numerous states and school systems to give students the exam.
#
# Another reason would be the SAT School Day Program, which allows students take the SAT during regular school hours usually at no cost, continues to exapnd. 36% fo the class of 2018 participated in the program, compared to 27% in 2017. Besides that, all income-eligible student can take the SAT for free with a fee waiver. Even if low-income students take the SAT during the school day, they can take the SAT again two more times, at no cost, on a weekend. Note all states pays for the student's SAT exam.
#
# Lastly, SAT's growth validated the decision to launch a new version in 2016 with less of the tricky vocabulary that was long a hallmark of the test. The new version also dropped the 'guessing penalty', a feature that deducted points for wrong answers. This makes SAT more straightforward and approachable.
#
# From the dataset provided to this project, it is obviously an incomplete data (E.g. missing of ACT 2018 other subjects mean score other than Composite.) We've searched SAT and ACT participation rate and mean scores for all subjects for year 2017 & 2018 to compare with dataset provided to clear any data errors. Also through research, participation rate is highly impact on the states policies and whether they are required to take SAT or ACT exam. These are facts contribute to the surge of SAT participation rate, We would take into consideration of some additional data as a suppliment to the analsysis.
#
# Additional 4 datasets-added into this project analyze:
#
# * [`sat_or_act_requirements.xlsx`](./data/sat_or_act_requirements.xlsx): states required for SAT or ACT
# * [`Census Bureau-designated regions and divisions(US_wiki).xlsx`](./data/Census-Bureau-designated-regions-and-divisions(US_wiki).xlsx): Census Bureau-designated regions and divisions of all US 51 States
# * [`Average ACT Scores (Source)_compared.xlsx`](./data/Average-ACT-Scores-(Source)_compared.xlsx): 2017 & 2018 ACT mean scores by States(published by Digest of Education Statistics)
# * [`Average SAT Scores (Source)_compared.xlsx`](./data/Average-SAT-Scores-(Source)_compared.xlsx): 2017 & 2018 SAT mean scores by States (published by Digest of Education Statistics)
#
#
# There are other data We could explore further in future analysis and improvement:
#
# 1. The population, race and geographic data for each state in the test taken year. Some states may face aging problem, or with low income might contribute to low or high participation rate on the test, or different race might have preference towards one tet (SAT or ACT).
# 2. The types of schools (private or public) that participated in SAT or ACT, this might show some trends on participation rate and average score.
# 3. High school students family income, to analyze if there's any correlation the higher partication rate with certain groups of family income. This could help us to target on the students family group and provide any free test/test fee waiver to other family income groups.
# 4. Parents education background--there's a possible pattern we could find if with this data, that higher educated parents have a higher influence on their children to achieve a higher test score.
#
#
# Resource:
# * https://blog.prepscholar.com/which-states-require-the-sat
# * https://nces.ed.gov/programs/digest/ (for SAT & ACT 2017,2018 mean scores source data)
# * https://simple.wikipedia.org/wiki/List_of_regions_of_the_United_States
# * https://newsroom.collegeboard.org/more-2-million-students-class-2018-took-sat-highest-ever
# * https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/
# * https://www.testive.com/colorado-sat-change-2017/
# * https://reports.collegeboard.org/archive/sat-suite-program-results/2018/class-2018-results

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#define a function to get mean of a list
def get_mean(num_lt):
    
    sum = 0
    i = 0
    
    for i in range(len(num_lt)):
        
        sum += num_lt[i]
    
    get_mean = sum / len(num_lt)
    
    return(get_mean)

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# To Calculate standard deviation
# get cumulative square sum of (Xi - u)
# calculate the standard deviation value follow the formula

def cal_sd(num_lt): 
    i = 0
    square_sum = 0
    u = get_mean(num_lt)

    for i in range(len(num_lt)):
        square_sum += (num_lt[i]- u) **2 

    sd_value = (square_sum / len(num_lt)) ** (1/2)
    
    return sd_value

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
#define a function to convert pecentage symbol into decimal percent 
def convert_to_float(n):
    n = n.replace('%','')
    n = float(n)/100
    return n

# %%
convert_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
#Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns

from IPython.display import Image #for load the images I did in Tableau

# %% [markdown]
# ## Data Import & Cleaning

# %% [markdown]
# ### 1. Read 2017 SAT & ACT data, and Display the data
# Read 2 files: "sat_2017.csv" and "act_2017.csv" and assign them into individual pandas dataframe.

# %%
path = "../data/"
sat_2017 = pd.read_csv(path + 'sat_2017.csv')
act_2017 = pd.read_csv(path + 'act_2017.csv')

# %%
# print the first 5 rows of each dataframe to your Jupyter notebook.
sat_2017.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2017.shape
# Out:
# (52, 7)

# %% [markdown]
# ### 2. Check for missing values

# %%
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# Answers: There's no missing data for sat_2017 & act_2017 dataset.

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# After checking the scroe range of "Evidence-Based Reading and Writing" & "Math".
#
# Actual both SAT 2 subjects their score range should be between 200 to 800, and Total score is in the range of 400 to 1600.
# But obviously there's 1 record of Math with the min value of 52 score, it could be an outlier might due to manual data input mistake. I will go through all data set to check if any other records that Math is below 200 scores.
#
# Reference source: https://collegereadiness.collegeboard.org/sat/scores/understanding-scores/interpreting

# %%
# To check if any Math score records is below 200
sat_2017[sat_2017['Math'] < 200]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# Comparing to the original dataset, there seems to be data entry error. Maryland's average math score should be 524 instead of 52.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# For Science there's a min of 2.3, it's likely to be an outlier.

# %%
act_2017[act_2017['Science'] == 2.3]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %% [markdown]
# By comparing with original dataset from: https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf, state Maryland the Science average score is 23.2 instead.

# %% [markdown]
# ### 4. Fix any errors you identified in steps 2-3

# %%
# Reset the Math score for sate "Maryland"
sat_2017.at[20,'Math'] = 524

# %%
# Reset the Science score for sate "Maryland"
act_2017.at[21,'Science'] = 23.2

# %%
# Re-check the statistics for sat_2017 after data correction
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# Re-check the statistics for act_2017 after data correction
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.442308
# std     2.332132   1.963602   2.048672   1.723351
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.475000  19.975000
# 50%    20.550000  20.900000  21.700000  21.300000
# 75%    23.300000  23.100000  24.125000  23.200000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# ### 5. Check on Data types

# %%
# Display the data types of each feature--sat_2017
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Display the data types of each feature--act_2017
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# ### 6.Fix any incorrect data types found in step 5.
# Fix any individual values preventing other columns from being the appropriate type.
# If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! Hint: use .map() or .apply().

# %%
# the Participation rate in both sat_2017 & act_2017 datasets is an object type, however it should be a float number.

# %%
sat_2017['Participation'] = sat_2017['Participation'].apply(convert_to_float)

# %%
sat_2017.head(5)
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_2017['Participation'] = act_2017['Participation'].apply(convert_to_float)

# %%
act_2017.head(5)
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
# display the data type, and found column "Composite" has incorrect data type
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# In act_2017 data, subject "Composite" data type is "object", I will go through further to check the all unique values for this column. There's a score of "20.2x", this could be a typo and I will correct the data by remove "x", and convert this column to float data type.

# %%
# get all unique values for "Composite" column 

act_2017['Composite'].unique()
# Out:
# array(['21.0', '19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2',
#        '24.1', '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7',
#        '20.0', '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4',
#        '20.3', '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7',
#        '24.0', '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %%
act_2017[act_2017['Composite'] == '20.2x']
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 51  Wyoming            1.0     19.4  19.8     20.8     20.6     20.2x

# %%
# Reset and remove the ending "x" for State "Wyoming"

act_2017.at[51,'Composite'] = 20.2

# %%
#display the data types to confirm they are all correct
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# define a function to convert into float data type
def composite_to_float(n):
    n = float(n)
    return n

# %%
# Call function to convert "Composite" to float type
act_2017['Composite'] = act_2017['Composite'].apply(composite_to_float)

# %%
#display the data types to confirm they are all correct
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# ### 7. Rename Columns
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_2017.columns = ['state', 'sat_17_participation', 'sat_17_ebrw', 'sat_17_math', 'sat_17_total']
sat_2017.head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act_2017.columns = ['state', 'act_17_participation', 'act_17_english', 'act_17_math', 'act_17_reading', 'act_17_science', 'act_17_composite']
act_2017.head()
# Out:
#       state  act_17_participation  act_17_english  act_17_math  \
# 0  National                  0.60            20.3         20.7
# 1   Alabama                  1.00            18.9         18.4
# 2    Alaska                  0.65            18.7         19.8
# 3   Arizona                  0.62            18.6         19.8
# 4  Arkansas                  1.00            18.9         19.0
#
#    act_17_reading  act_17_science  act_17_composite
# 0            21.4            21.0              21.0
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4

# %% [markdown]
# ### 8. Drop unnecessary rows (if needed).

# %% [markdown]
# In act_2017, there's a row of national average score for each subject, but "National" is not a state name and there's no corresponding records in sat_2017. I will drop this row before merge sat_2017 & act_2017 by State name.

# %%
act_2017.drop([0],inplace=True)

# %%
act_2017.head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 1     Alabama                  1.00            18.9         18.4
# 2      Alaska                  0.65            18.7         19.8
# 3     Arizona                  0.62            18.6         19.8
# 4    Arkansas                  1.00            18.9         19.0
# 5  California                  0.31            22.5         22.7
#
#    act_17_reading  act_17_science  act_17_composite
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4
# 5            23.1            22.2              22.8

# %%
act_2017.shape
# Out:
# (51, 7)

# %% [markdown]
# ### 9. Merge dataframes that can be merged.

# %%
combined_2017 = pd.merge(sat_2017, act_2017, on = 'state', how='left')
combined_2017.head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055
#
#    act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                  1.00            18.9         18.4            19.7
# 1                  0.65            18.7         19.8            20.4
# 2                  0.62            18.6         19.8            20.1
# 3                  1.00            18.9         19.0            19.7
# 4                  0.31            22.5         22.7            23.1
#
#    act_17_science  act_17_composite
# 0            19.4              19.2
# ...

# %%
# check combined dataset, null value count & data types to ensure there's no null value
combined_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   sat_17_participation  51 non-null     float64
#  2   sat_17_ebrw           51 non-null     int64
#  3   sat_17_math           51 non-null     int64
#  4   sat_17_total          51 non-null     int64
#  5   act_17_participation  51 non-null     float64
#  6   act_17_english        51 non-null     float64
#  7   act_17_math           51 non-null     float64
#  8   act_17_reading        51 non-null     float64
#  9   act_17_science        51 non-null     float64
#  10  act_17_composite      51 non-null     float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# ### 10. Perform any additional cleaning that you feel is necessary.

# %%
# After comparing by Excel v-loopup(as it's a small dataset and esay to compare in excel)
# please refer to /data/Average SAT Scores (Source)_compared.xlsx & Average ACT Scores (Source)_compared.xlsx
# I found other data errors in 2017 SAT & ACT data

#Error-1: State "District of Columbia" SAT 2017 Participation Rate shold be 0.9 instead of 1. 
combined_2017[combined_2017['state'] =='District of Columbia']
# Out:
#                   state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 8  District of Columbia                   1.0          482          468
#
#    sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 8           950                  0.32            24.4         23.5
#
#    act_17_reading  act_17_science  act_17_composite
# 8            24.9            23.5              24.2

# %%
combined_2017.at[8,'sat_17_participation'] = 0.9

# %%
combined_2017[combined_2017['state'] =='District of Columbia']
# Out:
#                   state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 8  District of Columbia                   0.9          482          468
#
#    sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 8           950                  0.32            24.4         23.5
#
#    act_17_reading  act_17_science  act_17_composite
# 8            24.9            23.5              24.2

# %%
#Error-2: there are 15 States their 2017 total sat score is not correct as it should be sum of each subject's score
incorrect_total=combined_2017[combined_2017['sat_17_total'] != combined_2017['sat_17_ebrw'] + combined_2017['sat_17_math']]
incorrect_total
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 6     Connecticut                  1.00          530          512
# 7        Delaware                  1.00          503          492
# 12          Idaho                  0.93          513          493
# 15           Iowa                  0.02          641          635
# 18      Louisiana                  0.04          611          586
# 21  Massachusetts                  0.76          555          551
# 22       Michigan                  1.00          509          495
# 24    Mississippi                  0.02          634          607
# 27       Nebraska                  0.03          629          625
# 32       New York                  0.67          528          523
# 35           Ohio                  0.12          578          570
# 39   Rhode Island                  0.71          539          524
# 41   South Dakota                  0.03          612          603
# ...

# %%
#reset sat_17_total value to be sum of sat_17_ebrw & sat_17_math
combined_2017['sat_17_total']=combined_2017['sat_17_ebrw'] + combined_2017['sat_17_math']

# %%
## choose one of above incorrect total row, to check and ensure the sat_17_total has reset value correctly
combined_2017.loc[6]
# Out:
# state                   Connecticut
# sat_17_participation              1
# sat_17_ebrw                     530
# sat_17_math                     512
# sat_17_total                   1042
# act_17_participation           0.31
# act_17_english                 25.5
# act_17_math                    24.6
# act_17_reading                 25.6
# act_17_science                 24.6
# act_17_composite               25.2
# Name: 6, dtype: object

# %% [markdown]
# ### 11. Save your cleaned and merged dataframes as csv files.

# %%
#save the combined & cleaned data for year 2017 into csv files under same path I stored all datasets

combined_2017.to_csv(path+'combined_2017.csv', index=False)

# %% [markdown]
# ### 12. Data Import & Cleaning (Import 2018 SAT & ACT Data)

# %% [markdown]
# Following the same approaches as I did above, I will import sat_2018 & act_2018 datasets, clean data, merge dataframes and then save as csv files for year 2018's.

# %%
#import sat_2018 dataset
sat_2018 = pd.read_csv(path+'sat_2018.csv')

#display first 5 rows of dataset
sat_2018.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#check how many records & columns 
sat_2018.shape

# there are complete 51 rows for US 51 states
# Out:
# (51, 5)

# %%
# check the statistics of sat_2018
sat_2018.describe()

# I cannot see any obvious data issues from below statistics table
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
# check data info (null value counts and data types)
sat_2018.info()

# Column "Participation" is object type and same as 2017's dataset, I will convert it into float later.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Convert column "Participation" to be float data type

sat_2018['Participation'] = sat_2018['Participation'].apply(convert_to_float)

# %%
# display first 5 rows to confirm the data types has been changed correct 

sat_2018.head(5)
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#import act_2018 dataset
act_2018 = pd.read_csv(path+'act_2018.csv')

#display first 5 rows of dataset
act_2018.head(5)
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
#check how many records & columns 

act_2018.shape

# there are complete 52 rows but it should be only 51 states in US. 
# Let me take a look further on the states name, there might be duplicate names or additional uncessary records
# Out:
# (52, 3)

# %%
# Check if any duplicate state names and keep the last occurrence of each set of duplicated values is set on False and all others on True

act_2018['State'].duplicated(keep='last')

# We can see the index row 19 is a duplicate state.
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# Name: State, dtype: bool

# %%
# check the state name same as the row index 19
act_2018[act_2018['State']==act_2018.loc[19]['State']]
# Out:
#     State Participation  Composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %%
# Remove duplicates as 2 rows same records for state "Maine"
act_2018.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
# Double checking the duplicates had been removed
act_2018.info() # check combined dataset, null value count & data types to ensure there's no null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   Composite      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
# Column "Participation" is object type and same as 2017's dataset, I will convert it into float 
act_2018['Participation'] = act_2018['Participation'].apply(convert_to_float)

# %%
# check the statistics of act_2018
act_2018.describe()

# I cannot see any obvious data issues from below statistics table
# Out:
#        Participation  Composite
# count      51.000000  51.000000
# mean        0.617255  21.496078
# std         0.340371   2.111583
# min         0.070000  17.700000
# 25%         0.285000  19.950000
# 50%         0.660000  21.300000
# 75%         1.000000  23.650000
# max         1.000000  25.600000

# %%
# double check act_2018 data type has been changed correctly
act_2018.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
# Rename the columns to be tally with 2018's dataset
sat_2018.columns = ['state', 'sat_18_participation', 'sat_18_ebrw', 'sat_18_math', 'sat_18_total']
sat_2018.head()
# Out:
#         state  sat_18_participation  sat_18_ebrw  sat_18_math  sat_18_total
# 0     Alabama                  0.06          595          571          1166
# 1      Alaska                  0.43          562          544          1106
# 2     Arizona                  0.29          577          572          1149
# 3    Arkansas                  0.05          592          576          1169
# 4  California                  0.60          540          536          1076

# %%
act_2018.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
# Rename the columns to be tally with 2017's dataset
act_2018.columns = ['state', 'act_18_participation', 'act_18_composite']
act_2018.head()
# Out:
#         state  act_18_participation  act_18_composite
# 0     Alabama                  1.00              19.1
# 1      Alaska                  0.33              20.8
# 2     Arizona                  0.66              19.2
# 3    Arkansas                  1.00              19.4
# 4  California                  0.27              22.7

# %%
#Combine sat_2018 & act_2018 dataset into one dataframe

combined_2018 = pd.merge(sat_2018, act_2018, on='state', how='left')

# %%
combined_2018.head()
# Out:
#         state  sat_18_participation  sat_18_ebrw  sat_18_math  sat_18_total  \
# 0     Alabama                  0.06          595          571          1166
# 1      Alaska                  0.43          562          544          1106
# 2     Arizona                  0.29          577          572          1149
# 3    Arkansas                  0.05          592          576          1169
# 4  California                  0.60          540          536          1076
#
#    act_18_participation  act_18_composite
# 0                  1.00              19.1
# 1                  0.33              20.8
# 2                  0.66              19.2
# 3                  1.00              19.4
# 4                  0.27              22.7

# %%
combined_2018
# Out:
#                    state  sat_18_participation  sat_18_ebrw  sat_18_math  \
# 0                Alabama                  0.06          595          571
# 1                 Alaska                  0.43          562          544
# 2                Arizona                  0.29          577          572
# 3               Arkansas                  0.05          592          576
# 4             California                  0.60          540          536
# 5               Colorado                  1.00          519          506
# 6            Connecticut                  1.00          535          519
# 7               Delaware                  1.00          505          492
# 8   District of Columbia                  0.92          497          480
# 9                Florida                  0.56          550          549
# 10               Georgia                  0.70          542          522
# 11                Hawaii                  0.56          480          530
# ...

# %%
# check combined dataset, null value count & data types to ensure there's no null value
combined_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   sat_18_participation  51 non-null     float64
#  2   sat_18_ebrw           51 non-null     int64
#  3   sat_18_math           51 non-null     int64
#  4   sat_18_total          51 non-null     int64
#  5   act_18_participation  50 non-null     float64
#  6   act_18_composite      50 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
# There's 1 null record for act_18 data after merging, most likely because of differnt state name in sat_2018 and act_2018
# by viewing combined data, index row 8 for state "District of Columbia" has NaN value for act_2018 dataset
# let me do further check the state name for this row in act_2018
act_2018.loc[8]['state']

# sat_2018 the state name is "District of Columbia", it's upper case "C" for "Columbia"
# I will rename the state name
# Out:
# 'District of columbia'

# %%
act_2018['state'][8] = "District of Columbia"
# Out:
# <ipython-input-81-fab88763f81d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   act_2018['state'][8] = "District of Columbia"

# %%
#ensure the state name has updated correctly
act_2018.loc[8]
# Out:
# state                   District of Columbia
# act_18_participation                    0.32
# act_18_composite                        23.6
# Name: 8, dtype: object

# %%
#Redo the Combine sat_2018 & act_2018 dataset into one dataframe
combined_2018 = pd.merge(sat_2018, act_2018, on='state',how='left')

# %%
# check combined dataset, null value count & data types to ensure there's no null value
combined_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   sat_18_participation  51 non-null     float64
#  2   sat_18_ebrw           51 non-null     int64
#  3   sat_18_math           51 non-null     int64
#  4   sat_18_total          51 non-null     int64
#  5   act_18_participation  51 non-null     float64
#  6   act_18_composite      51 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ### Perform any additional cleaning that you feel is necessary.

# %%
# After comparing by Excel v-loopup(as it's a small dataset and esay to compare in excel)
# please refer to /data/Average SAT Scores (Source)_compared.xlsx & Average ACT Scores (Source)_compared.xlsx
# I found other data errors in 2018 SAT & ACT data

# %%
#Error-1: there are 8 States their 2018 total sat score is not correct as it should be sum of each subject's score
incorrect_total=combined_2018[combined_2018['sat_18_total'] != combined_2018['sat_18_ebrw'] + combined_2018['sat_18_math']]
incorrect_total
# Out:
#              state  sat_18_participation  sat_18_ebrw  sat_18_math  \
# 3         Arkansas                  0.05          592          576
# 6      Connecticut                  1.00          535          519
# 7         Delaware                  1.00          505          492
# 16          Kansas                  0.04          633          631
# 22        Michigan                  1.00          511          499
# 31      New Mexico                  0.16          552          540
# 33  North Carolina                  0.52          554          543
# 45         Vermont                  0.64          565          554
# 50         Wyoming                  0.03          633          625
#
#     sat_18_total  act_18_participation  act_18_composite
# 3           1169                  1.00              19.4
# 6           1053                  0.26              25.6
# 7            998                  0.17              23.8
# 16          1265                  0.71              21.6
# ...

# %%
#reset sat_17_total value to be sum of sat_17_ebrw & sat_17_math
combined_2018['sat_18_total']=combined_2018['sat_18_ebrw'] + combined_2018['sat_18_math']

# %%
# choose one of above incorrect total row, to check and ensure the sat_18_total has reset value correctly
combined_2018.loc[3]
# Out:
# state                   Arkansas
# sat_18_participation        0.05
# sat_18_ebrw                  592
# sat_18_math                  576
# sat_18_total                1168
# act_18_participation           1
# act_18_composite            19.4
# Name: 3, dtype: object

# %%
#save the combined & cleaned data for year 2018 into csv files under same path I stored all datasets
combined_2018.to_csv(path+'combined_2018.csv', index=False)

# %% [markdown]
# ## Merge 2017 & 2018 combined & cleaned data into one dataframe

# %%
# Merging 2 years datasets into 1 dataframe and all following EDA will be on this dataframe
final = pd.merge(combined_2017, combined_2018, on='state',how='left') 
final.head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055
#
#    act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                  1.00            18.9         18.4            19.7
# 1                  0.65            18.7         19.8            20.4
# 2                  0.62            18.6         19.8            20.1
# 3                  1.00            18.9         19.0            19.7
# 4                  0.31            22.5         22.7            23.1
#
#    act_17_science  act_17_composite  sat_18_participation  sat_18_ebrw  \
# ...

# %%
final.columns
# Out:
# Index(['state', 'sat_17_participation', 'sat_17_ebrw', 'sat_17_math',
#        'sat_17_total', 'act_17_participation', 'act_17_english', 'act_17_math',
#        'act_17_reading', 'act_17_science', 'act_17_composite',
#        'sat_18_participation', 'sat_18_ebrw', 'sat_18_math', 'sat_18_total',
#        'act_18_participation', 'act_18_composite'],
#       dtype='object')

# %% [markdown]
# ### Merge additional data from outside research as a supplement to further analysis

# %%
#import sat_or_act_requirements data file
sat_act_required = pd.read_excel(path+'sat_or_act_requirements.xlsx')

#display first 5 rows of dataset
sat_act_required.head(5)
# Out:
#         state is_sat_required is_act_required
# 0     Alabama              No             Yes
# 1      Alaska              No              No
# 2     Arizona              No              No
# 3    Arkansas              No              No
# 4  California              No              No

# %%
final_add = pd.merge(final, sat_act_required, on='state',how='left') 
final_add.head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055
#
#    act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                  1.00            18.9         18.4            19.7
# 1                  0.65            18.7         19.8            20.4
# 2                  0.62            18.6         19.8            20.1
# 3                  1.00            18.9         19.0            19.7
# 4                  0.31            22.5         22.7            23.1
#
#    act_17_science  act_17_composite  sat_18_participation  sat_18_ebrw  \
# ...

# %%
final_add.columns
# Out:
# Index(['state', 'sat_17_participation', 'sat_17_ebrw', 'sat_17_math',
#        'sat_17_total', 'act_17_participation', 'act_17_english', 'act_17_math',
#        'act_17_reading', 'act_17_science', 'act_17_composite',
#        'sat_18_participation', 'sat_18_ebrw', 'sat_18_math', 'sat_18_total',
#        'act_18_participation', 'act_18_composite', 'is_sat_required',
#        'is_act_required'],
#       dtype='object')

# %%
#import Census Bureau-designated regions and divisions(US_wiki).xlsx data file

state_region = pd.read_excel(path+'Census Bureau-designated regions and divisions(US_wiki).xlsx')

#display first 5 rows of dataset
state_region.head(5)
# Out:
#            state     region     division
# 0    Connecticut  Northeast  New England
# 1          Maine  Northeast  New England
# 2  Massachusetts  Northeast  New England
# 3  New Hampshire  Northeast  New England
# 4   Rhode Island  Northeast  New England

# %%
final_add = pd.merge(final_add, state_region, on='state',how='left') 
final_add.head(10)
# Out:
#                   state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 0               Alabama                  0.05          593          572
# 1                Alaska                  0.38          547          533
# 2               Arizona                  0.30          563          553
# 3              Arkansas                  0.03          614          594
# 4            California                  0.53          531          524
# 5              Colorado                  0.11          606          595
# 6           Connecticut                  1.00          530          512
# 7              Delaware                  1.00          503          492
# 8  District of Columbia                  0.90          482          468
# 9               Florida                  0.83          520          497
#
#    sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 0          1165                  1.00            18.9         18.4
# ...

# %%
# 2017-2018 SAT & ACT merged data without any additional outside research data
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   sat_17_participation  51 non-null     float64
#  2   sat_17_ebrw           51 non-null     int64
#  3   sat_17_math           51 non-null     int64
#  4   sat_17_total          51 non-null     int64
#  5   act_17_participation  51 non-null     float64
#  6   act_17_english        51 non-null     float64
#  7   act_17_math           51 non-null     float64
#  8   act_17_reading        51 non-null     float64
#  9   act_17_science        51 non-null     float64
#  10  act_17_composite      51 non-null     float64
#  11  sat_18_participation  51 non-null     float64
#  12  sat_18_ebrw           51 non-null     int64
#  13  sat_18_math           51 non-null     int64
#  14  sat_18_total          51 non-null     int64
# ...

# %%
# 2017-2018 SAT & ACT merged data with the additional outside research data
final_add.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   sat_17_participation  51 non-null     float64
#  2   sat_17_ebrw           51 non-null     int64
#  3   sat_17_math           51 non-null     int64
#  4   sat_17_total          51 non-null     int64
#  5   act_17_participation  51 non-null     float64
#  6   act_17_english        51 non-null     float64
#  7   act_17_math           51 non-null     float64
#  8   act_17_reading        51 non-null     float64
#  9   act_17_science        51 non-null     float64
#  10  act_17_composite      51 non-null     float64
#  11  sat_18_participation  51 non-null     float64
#  12  sat_18_ebrw           51 non-null     int64
#  13  sat_18_math           51 non-null     int64
#  14  sat_18_total          51 non-null     int64
# ...

# %%
#save final merged 2 years datasets into csv files under same path I stored all datasets

final.to_csv(path+'final.csv', index=False)                          #cleaned data, without additional outside research data
final_add.to_csv(path+'final_with_additional_data.csv', index=False) #cleaned data, with additional outside research data. And will use it for further EDA & plotting

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# Blow has shown the data dictionary for the final dataset (consists of 2017-2018 SAT & ACT data):
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|SAT/ACT|US states name, total 51 states|
# |**sat_17_participation**|*float*|SAT|2017 SAT Mean participation rate, range: 0-1|
# |**sat_17_ebrw**|*int*|SAT|2017 SAT-mean score of Evidence-Based Reading and Writing, range: 200-800|
# |**sat_17_math**|*int*|SAT|2017 SAT-mean score of MATH, range: 200-800|
# |**sat_17_total**|*int*|SAT|2017 SAT mean total score, range: 400-1600|
# |**act_17_participation**|*float*|ACT|2017 ACT Mean participation rate, range: 0-1|
# |**act_17_english**|*float*|ACT|2017 ACT mean score of English, range: 1-36|
# |**act_17_math**|*float*|ACT|2017 ACT mean score of MATH, range: 1-36|
# |**act_17_reading**|*float*|ACT|2017 ACT mean score of READING, range: 1-36|
# |**act_17_science**|*float*|ACT|2017 ACT mean score of SCIENCE, range: 1-36|
# |**act_17_composite**|*float*|ACT|2017 ACT mean score of COMPOSITION, range: 1-36|
# |**sat_18_participation**|*float*|SAT|2018 SAT Mean participation rate, range: 0-1|
# |**sat_18_ebrw**|*int*|SAT|2018 SAT-mean score of Evidence-Based Reading and Writing, range: 200-800|
# |**sat_18_math**|*int*|SAT|2018 SAT-mean score of MATH, range: 200-800|
# |**sat_18_total**|*int*|SAT|2017 SAT mean total score, range: 400-1600|
# |**act_18_participation**|*float*|ACT|2017 ACT Mean participation rate, range: 0-1|
# |**act_18_composite**|*float*|ACT|2017 ACT mean score of COMPOSITION, range: 1-36|
# |**is_sat_required**|*object*|SAT/ACT|The state requires or not require SAT test, value: Yes/No|
# |**is_act_required**|*object*|SAT/ACT|The state requires or not require ACT test, value: Yes/No|
# |**region**|*object*|SAT/ACT|Regions for each state, total 4 regions|
# |**division**|*object*|SAT/ACT|Divisions for each state, total 9 divisions|

# %%
final_add.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   sat_17_participation  51 non-null     float64
#  2   sat_17_ebrw           51 non-null     int64
#  3   sat_17_math           51 non-null     int64
#  4   sat_17_total          51 non-null     int64
#  5   act_17_participation  51 non-null     float64
#  6   act_17_english        51 non-null     float64
#  7   act_17_math           51 non-null     float64
#  8   act_17_reading        51 non-null     float64
#  9   act_17_science        51 non-null     float64
#  10  act_17_composite      51 non-null     float64
#  11  sat_18_participation  51 non-null     float64
#  12  sat_18_ebrw           51 non-null     int64
#  13  sat_18_math           51 non-null     int64
#  14  sat_18_total          51 non-null     int64
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1. Summary Statistics.

# %%
final_add.describe().transpose()
# Out:
#                       count         mean        std     min       25%  \
# sat_17_participation   51.0     0.396078   0.349617    0.02     0.040
# sat_17_ebrw            51.0   569.117647  45.666901  482.00   533.500
# sat_17_math            51.0   556.882353  47.121395  468.00   523.500
# sat_17_total           51.0  1126.000000  92.487621  950.00  1055.500
# act_17_participation   51.0     0.652549   0.321408    0.08     0.310
# act_17_english         51.0    20.931373   2.353677   16.30    19.000
# act_17_math            51.0    21.182353   1.981989   18.00    19.400
# act_17_reading         51.0    22.013725   2.067271   18.10    20.450
# act_17_science         51.0    21.450980   1.739353   18.20    19.950
# act_17_composite       51.0    21.519608   2.020695   17.80    19.800
# sat_18_participation   51.0     0.457451   0.373143    0.02     0.045
# sat_18_ebrw            51.0   563.686275  47.502627  480.00   534.500
# ...

# %% [markdown]
# ### 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# Call the function cal_sd to calculate the standard diviation use dictionary comprehension  
sd={i:cal_sd(final_add[i]) for i in final_add.columns if final_add[i].dtypes != object}
print(sd)
# Out:
# {'sat_17_participation': 0.34617279166863635, 'sat_17_ebrw': 45.21697020437866, 'sat_17_math': 46.65713364485503, 'sat_17_total': 91.57639048421622, 'act_17_participation': 0.3182417575123181, 'act_17_english': 2.3304876369363363, 'act_17_math': 1.9624620273436781, 'act_17_reading': 2.0469029314842646, 'act_17_science': 1.7222161451443676, 'act_17_composite': 2.000786081581989, 'sat_18_participation': 0.3694661922353942, 'sat_18_ebrw': 47.03460978357609, 'sat_18_math': 47.30194550378352, 'sat_18_total': 93.26114360945468, 'act_18_participation': 0.33701735820410317, 'act_18_composite': 2.090779082141178}

# %%
# Standard Deviation using np.std to compare my above calculation, ensure the result is same
final_add.iloc[:,1:17].apply(np.std)
# Out:
# sat_17_participation     0.346173
# sat_17_ebrw             45.216970
# sat_17_math             46.657134
# sat_17_total            91.576390
# act_17_participation     0.318242
# act_17_english           2.330488
# act_17_math              1.962462
# act_17_reading           2.046903
# act_17_science           1.722216
# act_17_composite         2.000786
# sat_18_participation     0.369466
# sat_18_ebrw             47.034610
# sat_18_math             47.301946
# sat_18_total            93.261144
# act_18_participation     0.337017
# act_18_composite         2.090779
# dtype: float64

# %% [markdown]
# ### 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):

# %% [markdown]
# #### 3.1 Which states have the highest and lowest participation rates for the 2017 or 2018 SAT and ACT?

# %%
final_add.head(5)
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055
#
#    act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                  1.00            18.9         18.4            19.7
# 1                  0.65            18.7         19.8            20.4
# 2                  0.62            18.6         19.8            20.1
# 3                  1.00            18.9         19.0            19.7
# 4                  0.31            22.5         22.7            23.1
#
#    act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# ...

# %%
# Get the lowest sat_17 participation rate
final_add.sort_values('sat_17_participation').head()
# Out:
#            state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 34  North Dakota                  0.02          635          621
# 24   Mississippi                  0.02          634          607
# 15          Iowa                  0.02          641          635
# 25      Missouri                  0.03          640          631
# 44          Utah                  0.03          624          614
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 34          1256                  0.98            19.0         20.4
# 24          1241                  1.00            18.2         18.1
# 15          1276                  0.67            21.2         21.3
# 25          1271                  1.00            19.8         19.9
# 44          1238                  1.00            19.5         19.9
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 34            20.5            20.6  ...                  0.02          640
# ...

# %%
final_add[final_add['sat_17_participation'] == 0.02][['state','region']]
# Out:
#            state   region
# 15          Iowa  Midwest
# 24   Mississippi    South
# 34  North Dakota  Midwest

# %% [markdown]
# 3 states have the lowest SAT Test participation rate-0.02 in 2017:
# * Iowa
# * Mississippi
# * North Dakota

# %%
# Get the highest sat_17 participation rate
final_add.sort_values('sat_17_participation',ascending=False).head()
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 22       Michigan                  1.00          509          495
# 6     Connecticut                  1.00          530          512
# 7        Delaware                  1.00          503          492
# 29  New Hampshire                  0.96          532          520
# 19          Maine                  0.95          513          499
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 22          1004                  0.29            24.1         23.7
# 6           1042                  0.31            25.5         24.6
# 7            995                  0.18            24.1         23.4
# 29          1052                  0.18            25.4         25.1
# 19          1012                  0.08            24.2         24.0
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 22            24.5            23.8  ...                  1.00          511
# ...

# %%
final_add[final_add['sat_17_participation'] == 1][['state','region']]
# Out:
#           state     region
# 6   Connecticut  Northeast
# 7      Delaware      South
# 22     Michigan    Midwest

# %% [markdown]
# 3 states have the highest SAT test participation rate-100% in 2017:
# * Connecticut
# * Delaware
# * Michigan

# %%
# Get the lowest sat_18 participation rate
final_add.sort_values('sat_18_participation').head()
# Out:
#            state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 34  North Dakota                  0.02          635          621
# 50       Wyoming                  0.03          626          604
# 41  South Dakota                  0.03          612          603
# 27      Nebraska                  0.03          629          625
# 49     Wisconsin                  0.03          642          649
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 34          1256                  0.98            19.0         20.4
# 50          1230                  1.00            19.4         19.8
# 41          1215                  0.80            20.7         21.5
# 27          1254                  0.84            20.9         20.9
# 49          1291                  1.00            19.7         20.4
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 34            20.5            20.6  ...                  0.02          640
# ...

# %% [markdown]
# The state has the lowest SAT Test participation rate-0.02 in 2018:
# * North Dakota

# %%
# Get the highest sat_18 participation rate
final_add.sort_values('sat_18_participation',ascending=False).head(6)
# Out:
#           state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 5      Colorado                  0.11          606          595          1201
# 6   Connecticut                  1.00          530          512          1042
# 7      Delaware                  1.00          503          492           995
# 22     Michigan                  1.00          509          495          1004
# 12        Idaho                  0.93          513          493          1006
# 19        Maine                  0.95          513          499          1012
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 5                   1.00            20.1         20.3            21.2
# 6                   0.31            25.5         24.6            25.6
# 7                   0.18            24.1         23.4            24.8
# 22                  0.29            24.1         23.7            24.5
# 12                  0.38            21.9         21.8            23.0
# ...

# %%
final_add[final_add['sat_18_participation'] == 1][['state','region']]
# Out:
#           state     region
# 5      Colorado       West
# 6   Connecticut  Northeast
# 7      Delaware      South
# 12        Idaho       West
# 22     Michigan    Midwest

# %%
len(final_add[final_add['sat_18_participation'] == 1]['state'])
# Out:
# 5

# %% [markdown]
# 5 states have the highest SAT test participation rate-100% in 2018:
# * Colorado
# * Connecticut
# * Delaware
# * Idaho
# * Michigan

# %%
# Get the lowest act_17 participation rate
final_add.sort_values('act_17_participation').head()
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 19          Maine                  0.95          513          499
# 29  New Hampshire                  0.96          532          520
# 7        Delaware                  1.00          503          492
# 39   Rhode Island                  0.71          539          524
# 38   Pennsylvania                  0.65          540          531
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 19          1012                  0.08            24.2         24.0
# 29          1052                  0.18            25.4         25.1
# 7            995                  0.18            24.1         23.4
# 39          1063                  0.21            24.0         23.3
# 38          1071                  0.23            23.4         23.4
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 19            24.8            23.7  ...                  0.99          512
# ...

# %% [markdown]
# States have the lowest ACT participation rate-0.08 in 2017:
# * Maine

# %%
# Get the highest act_17 participation rate
final_add.sort_values('act_17_participation',ascending=False).head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 17   Kentucky                  0.04          631          616          1247
# 49  Wisconsin                  0.03          642          649          1291
# 44       Utah                  0.03          624          614          1238
# 42  Tennessee                  0.05          623          604          1227
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                    1.0            18.9         18.4            19.7
# 17                   1.0            19.6         19.4            20.5
# 49                   1.0            19.7         20.4            20.6
# 44                   1.0            19.5         19.9            20.8
# 42                   1.0            19.5         19.2            20.1
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# ...

# %%
final_add[final_add['act_17_participation'] == 1][['state','region']]
# Out:
#              state   region
# 0          Alabama    South
# 3         Arkansas    South
# 5         Colorado     West
# 17        Kentucky    South
# 18       Louisiana    South
# 23       Minnesota  Midwest
# 24     Mississippi    South
# 25        Missouri  Midwest
# 26         Montana     West
# 28          Nevada     West
# 33  North Carolina    South
# 36        Oklahoma    South
# 40  South Carolina    South
# 42       Tennessee    South
# 44            Utah     West
# 49       Wisconsin  Midwest
# 50         Wyoming     West

# %%
len(final_add[final_add['act_17_participation'] == 1]['state'])
# Out:
# 17

# %% [markdown]
# 17 states have the highest ACT test participation rate-100% in 2017:
# * Alabama
# * Arkansas
# * Colorado
# * Kentucky
# * Louisiana
# * Minnesota
# * Mississippi
# * Missouri
# * Montana
# * Nevada
# * North Carolina
# * Oklahoma
# * South Carolina
# * Tennessee
# * Utah
# * Wisconsin
# * Wyoming

# %%
# Get the lowest act_18 participation rate
final_add.sort_values('act_18_participation').head()
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 19          Maine                  0.95          513          499
# 39   Rhode Island                  0.71          539          524
# 29  New Hampshire                  0.96          532          520
# 7        Delaware                  1.00          503          492
# 38   Pennsylvania                  0.65          540          531
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 19          1012                  0.08            24.2         24.0
# 39          1063                  0.21            24.0         23.3
# 29          1052                  0.18            25.4         25.1
# 7            995                  0.18            24.1         23.4
# 38          1071                  0.23            23.4         23.4
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 19            24.8            23.7  ...                  0.99          512
# ...

# %% [markdown]
# States have the lowest ACT participation rate-0.07 in 2018:
# * Maine

# %%
# Get the highest act_18 participation rate
final_add.sort_values('act_18_participation',ascending=False).head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 17   Kentucky                  0.04          631          616          1247
# 49  Wisconsin                  0.03          642          649          1291
# 44       Utah                  0.03          624          614          1238
# 42  Tennessee                  0.05          623          604          1227
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                    1.0            18.9         18.4            19.7
# 17                   1.0            19.6         19.4            20.5
# 49                   1.0            19.7         20.4            20.6
# 44                   1.0            19.5         19.9            20.8
# 42                   1.0            19.5         19.2            20.1
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# ...

# %%
final_add[final_add['act_18_participation'] == 1][['state','region']]
# Out:
#              state   region
# 0          Alabama    South
# 3         Arkansas    South
# 17        Kentucky    South
# 18       Louisiana    South
# 24     Mississippi    South
# 25        Missouri  Midwest
# 26         Montana     West
# 27        Nebraska  Midwest
# 28          Nevada     West
# 33  North Carolina    South
# 35            Ohio  Midwest
# 36        Oklahoma    South
# 40  South Carolina    South
# 42       Tennessee    South
# 44            Utah     West
# 49       Wisconsin  Midwest
# 50         Wyoming     West

# %%
# get total how many states that having same highest act_18 participation rate
len(final_add[final_add['act_18_participation'] == 1]['state'])
# Out:
# 17

# %% [markdown]
# 17 stats have the highest ACT participation rate-100% in 2018:
# * Alabama
# * Arkansas
# * Kentucky
# * Louisiana
# * Mississippi
# * Missouri
# * Montana
# * Nebraska
# * Nevada
# * North Carolina
# * Ohio
# * Oklahoma
# * South Carolina
# * Tennessee
# * Utah
# * Wisconsin
# * Wyoming

# %% [markdown]
# #### 3.2 Which states have the highest and lowest mean total/composite scores for the 2017 or 2018 SAT and ACT??

# %%
# Get the lowest sat_17 mean total scores
final_add.sort_values('sat_17_total').head()
# Out:
#                    state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 8   District of Columbia                  0.90          482          468
# 7               Delaware                  1.00          503          492
# 22              Michigan                  1.00          509          495
# 12                 Idaho                  0.93          513          493
# 19                 Maine                  0.95          513          499
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 8            950                  0.32            24.4         23.5
# 7            995                  0.18            24.1         23.4
# 22          1004                  0.29            24.1         23.7
# 12          1006                  0.38            21.9         21.8
# 19          1012                  0.08            24.2         24.0
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# ...

# %% [markdown]
# States have the lowest total SAT Scores 950 in 2017:
# * District of Columbia

# %%
# Get the highest sat_17 mean total scores
final_add.sort_values('sat_17_total',ascending=False).head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 23  Minnesota                  0.03          644          651          1295
# 49  Wisconsin                  0.03          642          649          1291
# 15       Iowa                  0.02          641          635          1276
# 25   Missouri                  0.03          640          631          1271
# 16     Kansas                  0.04          632          628          1260
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 23                  1.00            20.4         21.5            21.8
# 49                  1.00            19.7         20.4            20.6
# 15                  0.67            21.2         21.3            22.6
# 25                  1.00            19.8         19.9            20.8
# 16                  0.73            21.1         21.3            22.3
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# ...

# %% [markdown]
# States have the highest mean total SAT Scores 1295 in 2017:
# * Minnesota

# %%
# Get the lowest sat_18 mean total scores
final_add.sort_values('sat_18_total').head()
# Out:
#                    state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 8   District of Columbia                  0.90          482          468
# 7               Delaware                  1.00          503          492
# 48         West Virginia                  0.14          558          528
# 12                 Idaho                  0.93          513          493
# 44                  Utah                  0.03          624          614
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 8            950                  0.32            24.4         23.5
# 7            995                  0.18            24.1         23.4
# 48          1086                  0.69            20.0         19.4
# 12          1006                  0.38            21.9         21.8
# 44          1238                  1.00            19.5         19.9
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# ...

# %% [markdown]
# States have the lowest mean total SAT Scores 977 in 2018:
# * District of Columbia

# %%
# Get the highest sat_18 mean total scores
final_add.sort_values('sat_18_total',ascending=False).head()
# Out:
#            state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 23     Minnesota                  0.03          644          651
# 49     Wisconsin                  0.03          642          649
# 34  North Dakota                  0.02          635          621
# 15          Iowa                  0.02          641          635
# 16        Kansas                  0.04          632          628
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 23          1295                  1.00            20.4         21.5
# 49          1291                  1.00            19.7         20.4
# 34          1256                  0.98            19.0         20.4
# 15          1276                  0.67            21.2         21.3
# 16          1260                  0.73            21.1         21.3
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 23            21.8            21.6  ...                  0.04          643
# ...

# %% [markdown]
# States have the highest mean total SAT Scores 1298 in 2018:
# * Minnesota

# %%
# Get the lowest act_17 mean composite scores
final_add.sort_values('act_17_composite').head()
# Out:
#              state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 28          Nevada                  0.26          563          553
# 24     Mississippi                  0.02          634          607
# 40  South Carolina                  0.50          543          521
# 11          Hawaii                  0.55          544          541
# 33  North Carolina                  0.49          546          535
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 28          1116                   1.0            16.3         18.0
# 24          1241                   1.0            18.2         18.1
# 40          1064                   1.0            17.5         18.6
# 11          1085                   0.9            17.8         19.2
# 33          1081                   1.0            17.8         19.3
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# ...

# %% [markdown]
# States have the lowest mean composition ACT Scores 17.8 in 2017:
# * Nevada

# %%
# Get the highest act_17 mean composite scores
final_add.sort_values('act_17_composite',ascending=False).head()
# Out:
#                    state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 29         New Hampshire                  0.96          532          520
# 21         Massachusetts                  0.76          555          551
# 6            Connecticut                  1.00          530          512
# 19                 Maine                  0.95          513          499
# 8   District of Columbia                  0.90          482          468
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 29          1052                  0.18            25.4         25.1
# 21          1106                  0.29            25.4         25.3
# 6           1042                  0.31            25.5         24.6
# 19          1012                  0.08            24.2         24.0
# 8            950                  0.32            24.4         23.5
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# ...

# %%
final_add[final_add['state']=='New Hampshire']['act_17_composite']
# Out:
# 29    25.5
# Name: act_17_composite, dtype: float64

# %%
final_add[final_add['act_17_composite'] == 25.5][['state','region']]
# Out:
#             state     region
# 29  New Hampshire  Northeast

# %% [markdown]
# States have the highest mean composition ACT Scores 25.5 in 2017:
# * New Hampshire

# %%
# Get the lowest act_18 mean composite scores
final_add.sort_values('act_18_composite').head()
# Out:
#              state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 28          Nevada                  0.26          563          553
# 40  South Carolina                  0.50          543          521
# 24     Mississippi                  0.02          634          607
# 11          Hawaii                  0.55          544          541
# 0          Alabama                  0.05          593          572
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 28          1116                   1.0            16.3         18.0
# 40          1064                   1.0            17.5         18.6
# 24          1241                   1.0            18.2         18.1
# 11          1085                   0.9            17.8         19.2
# 0           1165                   1.0            18.9         18.4
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# ...

# %% [markdown]
# States have the lowest mean composition ACT Scores 17.7 in 2018:
# * Nevada

# %%
# Get the highest act_18 mean composite scores
final_add.sort_values('act_18_composite',ascending=False).head()
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 6     Connecticut                  1.00          530          512
# 21  Massachusetts                  0.76          555          551
# 29  New Hampshire                  0.96          532          520
# 32       New York                  0.67          528          523
# 22       Michigan                  1.00          509          495
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 6           1042                  0.31            25.5         24.6
# 21          1106                  0.29            25.4         25.3
# 29          1052                  0.18            25.4         25.1
# 32          1051                  0.31            23.8         24.0
# 22          1004                  0.29            24.1         23.7
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# 6             25.6            24.6  ...                  1.00          535
# ...

# %% [markdown]
# States have the highest mean composition ACT Scores 25.6 in 2018:
# * Connecticut

# %% [markdown]
# #### 3.3 Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
final_add[(final_add['sat_17_participation'] == 1) > final_add['sat_18_participation']]
# Out:
# Empty DataFrame
# Columns: [state, sat_17_participation, sat_17_ebrw, sat_17_math, sat_17_total, act_17_participation, act_17_english, act_17_math, act_17_reading, act_17_science, act_17_composite, Composite, sat_18_participation, sat_18_ebrw, sat_18_math, sat_18_total, act_18_participation, act_18_composite, is_sat_required, is_act_required, region, division]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# States decresed the SAT participation rate from 100%: (by comparing the participation rate in year 2017 & 2018)
# * District of Columbia
#
# Decreased from 100% to 92%, with a 8% drease.

# %%
final_add[(final_add['sat_18_participation'] == 1) > final_add['sat_17_participation']]
# Out:
#        state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 5   Colorado                  0.11          606          595          1201
# 12     Idaho                  0.93          513          493          1006
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 5                   1.00            20.1         20.3            21.2
# 12                  0.38            21.9         21.8            23.0
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# 5             20.9  ...                   1.0          519          506
# 12            22.1  ...                   1.0          508          493
#
#     sat_18_total  act_18_participation  act_18_composite  is_sat_required  \
# 5           1025                  0.30              23.9              Yes
# 12          1001                  0.36              22.3               No
#
#     is_act_required region  division
# 5                No   West  Mountain
# ...

# %% [markdown]
# 2 States increased the SAT participation rate to 100%: (by comparing the participation rate in year 2017 & 2018)
# * Colorado: it's a quite big increase from 11% to 100%, increased by 89%.
# * Idaho: compare to state "Colorado", Idaho has a slightly small increase of 7%, from 93% increased to 100%.
#
# With the outside research https://blog.prepscholar.com/which-states-require-the-sat, all Colorado juniors in public schools will take the SAT. And each year, Idaho offers a free administration of the SAT to high school joniors.
#
# Above strategies helping to imprive state SAT participation rate is a good reference to College Board for future recommendations.

# %%
final_add[(final_add['act_17_participation'] == 1) > final_add['act_18_participation']]
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 5    Colorado                  0.11          606          595          1201
# 23  Minnesota                  0.03          644          651          1295
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 5                    1.0            20.1         20.3            21.2
# 23                   1.0            20.4         21.5            21.8
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# 5             20.9  ...                  1.00          519          506
# 23            21.6  ...                  0.04          643          655
#
#     sat_18_total  act_18_participation  act_18_composite  is_sat_required  \
# 5           1025                  0.30              23.9              Yes
# 23          1298                  0.99              21.3               No
#
#     is_act_required   region            division
# ...

# %% [markdown]
# States decresed the ACT participation rate from 100%: (by comparing the participation rate in year 2017 & 2018)
# * Colorado: decreased to 30%, with a 70% decreasing.
# Linked up with above SAT test increasing analysis, We coulde see Colorado is one of the states that has increased SAT participations while decreasing the participation in ACT test. That can partially explain why SAT increases as well.
#
# * Minnesota: has a very little of 1% decreasing to 99% participation rate.

# %%
final_add[(final_add['act_18_participation'] == 1) > final_add['act_17_participation']]
# Out:
#        state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 27  Nebraska                  0.03          629          625          1254
# 35      Ohio                  0.12          578          570          1148
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 27                  0.84            20.9         20.9            21.9
# 35                  0.75            21.2         21.6            22.5
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# 27            21.5  ...                  0.03          629          623
# 35            22.0  ...                  0.18          552          547
#
#     sat_18_total  act_18_participation  act_18_composite  is_sat_required  \
# 27          1252                   1.0              20.1               No
# 35          1099                   1.0              20.3              Yes
#
#     is_act_required   region             division
# ...

# %% [markdown]
# States increased the ACT participation rate to 100%: (by comparing the participation rate in year 2017 & 2018)
#
# * Nebraska: increased from 84%, with a 16%'s increasing.
# * Ohio: increased from 75%, with a 25% increasing.

# %% [markdown]
# #### 3.4 Do any states show have >50% participation on *both* tests each year?

# %%
final_add[(final_add['sat_17_participation'] > 0.5) & (final_add['act_17_participation'] > 0.5)]
# Out:
#       state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 9   Florida                  0.83          520          497          1017
# 10  Georgia                  0.61          535          515          1050
# 11   Hawaii                  0.55          544          541          1085
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 9                   0.73            19.0         19.4            21.0
# 10                  0.55            21.0         20.9            22.0
# 11                  0.90            17.8         19.2            19.2
#
#     act_17_science  ...  sat_18_participation  sat_18_ebrw  sat_18_math  \
# 9             19.4  ...                  0.56          550          549
# 10            21.3  ...                  0.70          542          522
# 11            19.3  ...                  0.56          480          530
#
#     sat_18_total  act_18_participation  act_18_composite  is_sat_required  \
# ...

# %% [markdown]
# In 2017, these 3 states have >50% participation on both SAT & ACT tests:
# * Florida
# * Georgia
# * Hawaii

# %%
final_add[(final_add['sat_18_participation'] > 0.5) & (final_add['act_18_participation'] > 0.5)]
# Out:
#              state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 9          Florida                  0.83          520          497
# 10         Georgia                  0.61          535          515
# 11          Hawaii                  0.55          544          541
# 33  North Carolina                  0.49          546          535
# 40  South Carolina                  0.50          543          521
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 9           1017                  0.73            19.0         19.4
# 10          1050                  0.55            21.0         20.9
# 11          1085                  0.90            17.8         19.2
# 33          1081                  1.00            17.8         19.3
# 40          1064                  1.00            17.5         18.6
#
#     act_17_reading  act_17_science  ...  sat_18_participation  sat_18_ebrw  \
# ...

# %% [markdown]
# In 2018, these 5 states have >50% participation on both SAT & ACT tests:
# * Florida
# * Georgia
# * Hawaii
# * North Carolina
# * South Carolina
#
# Comparing to last year, 2 more states have > 50% participation on both tests.

# %% [markdown]
# #### 3.5 Do any states increased or decreased participation on a test year-to-year?

# %%
# create 2 new columns to get the sat_trend & act_trend
# if sat_trend >0, means SAT participation rate increase year over year. Otherwise, decreased or remained the same. 
# if act_trend >0, means ACT participation rate increase year over year. Otherwise, decreased or remained the same.

final_add['sat_trend']=final_add['sat_18_participation']-final_add['sat_17_participation']
final_add['act_trend']=final_add['act_18_participation']-final_add['act_17_participation']
final_add.head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055
#
#    act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                  1.00            18.9         18.4            19.7
# 1                  0.65            18.7         19.8            20.4
# 2                  0.62            18.6         19.8            20.1
# 3                  1.00            18.9         19.0            19.7
# 4                  0.31            22.5         22.7            23.1
#
#    act_17_science  ...  sat_18_math  sat_18_total  act_18_participation  \
# ...

# %%
# check states has increased SAT participation rate
ins_sat = final_add[final_add['sat_trend'] > 0][['state','region']]
ins_sat
# Out:
#                    state     region
# 0                Alabama      South
# 1                 Alaska       West
# 3               Arkansas      South
# 4             California       West
# 5               Colorado       West
# 8   District of Columbia      South
# 10               Georgia      South
# 11                Hawaii       West
# 12                 Idaho       West
# 13              Illinois    Midwest
# 15                  Iowa    Midwest
# 19                 Maine  Northeast
# 20              Maryland      South
# 21         Massachusetts  Northeast
# 23             Minnesota    Midwest
# 24           Mississippi      South
# 25              Missouri    Midwest
# 30            New Jersey  Northeast
# 31            New Mexico       West
# 32              New York  Northeast
# 33        North Carolina      South
# 35                  Ohio    Midwest
# 36              Oklahoma      South
# 37                Oregon       West
# 38          Pennsylvania  Northeast
# ...

# %%
len(ins_sat)
# Out:
# 33

# %% [markdown]
# There are 33 states have increased their SAT participation rate year over year.

# %%
# check states has decreased SAT participation rate
des_sat = final_add[final_add['sat_trend'] < 0][['state','region']]
des_sat
# Out:
#       state region
# 2   Arizona   West
# 9   Florida  South
# 28   Nevada   West

# %% [markdown]
# There are 4 states have decreased their SAT participation rate year over year.
#
# Comparing the increased count of states, lesser states decreased their participation rate.

# %%
# check states has increased ACT participation rate
ins_act = final_add[final_add['act_trend'] > 0][['state','region']]
ins_act
# Out:
#          state   region
# 2      Arizona     West
# 15        Iowa  Midwest
# 20    Maryland    South
# 27    Nebraska  Midwest
# 31  New Mexico     West
# 35        Ohio  Midwest
# 37      Oregon     West

# %% [markdown]
# There are 7 states have increased their ACT participation rate year over year.
#
# Comparing the increased count of states for SAT test, lesser states increased their SAT participation rate.

# %%
# check states has decreased ACT participation rate
des_act = final_add[final_add['act_trend'] < 0][['state','region']]
des_act
# Out:
#             state     region
# 1          Alaska       West
# 4      California       West
# 5        Colorado       West
# 6     Connecticut  Northeast
# 7        Delaware      South
# 9         Florida      South
# 10        Georgia      South
# 11         Hawaii       West
# 12          Idaho       West
# 13       Illinois    Midwest
# 14        Indiana    Midwest
# 16         Kansas    Midwest
# 19          Maine  Northeast
# 21  Massachusetts  Northeast
# 22       Michigan    Midwest
# 23      Minnesota    Midwest
# 29  New Hampshire  Northeast
# 30     New Jersey  Northeast
# 32       New York  Northeast
# 38   Pennsylvania  Northeast
# 39   Rhode Island  Northeast
# 41   South Dakota    Midwest
# 45        Vermont  Northeast
# 46       Virginia      South
# 47     Washington       West
# 48  West Virginia      South

# %%
len(des_act)
# Out:
# 26

# %%
# Get the largest increase changes in ACT participation
final_add.nlargest(5,'act_trend')
# Out:
#        state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 35      Ohio                  0.12          578          570          1148
# 27  Nebraska                  0.03          629          625          1254
# 2    Arizona                  0.30          563          553          1116
# 20  Maryland                  0.69          536          524          1060
# 37    Oregon                  0.43          560          548          1108
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 35                  0.75            21.2         21.6            22.5
# 27                  0.84            20.9         20.9            21.9
# 2                   0.62            18.6         19.8            20.1
# 20                  0.28            23.3         23.1            24.2
# 37                  0.40            21.2         21.5            22.4
#
#     act_17_science  ...  act_18_participation  act_18_composite  \
# ...

# %%
# Get the largest decrease changes in ACT participation
final_add.nsmallest(5,'act_trend')
# Out:
#        state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 5   Colorado                  0.11          606          595          1201
# 13  Illinois                  0.09          559          556          1115
# 1     Alaska                  0.38          547          533          1080
# 22  Michigan                  1.00          509          495          1004
# 9    Florida                  0.83          520          497          1017
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 5                   1.00            20.1         20.3            21.2
# 13                  0.93            21.0         21.2            21.6
# 1                   0.65            18.7         19.8            20.4
# 22                  0.29            24.1         23.7            24.5
# 9                   0.73            19.0         19.4            21.0
#
#     act_17_science  ...  act_18_participation  act_18_composite  \
# ...

# %%
final_add[['state','act_trend']].sort_values('act_trend').head()
# Out:
#        state  act_trend
# 5   Colorado      -0.70
# 13  Illinois      -0.50
# 1     Alaska      -0.32
# 22  Michigan      -0.07
# 9    Florida      -0.07

# %%
# Get the largest increase changes in sat participation
final_add.nlargest(5,'sat_trend')
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 13       Illinois                  0.09          559          556
# 5        Colorado                  0.11          606          595
# 39   Rhode Island                  0.71          539          524
# 48  West Virginia                  0.14          558          528
# 30     New Jersey                  0.70          530          526
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 13          1115                  0.93            21.0         21.2
# 5           1201                  1.00            20.1         20.3
# 39          1063                  0.21            24.0         23.3
# 48          1086                  0.69            20.0         19.4
# 30          1056                  0.34            23.8         23.8
#
#     act_17_reading  act_17_science  ...  act_18_participation  \
# 13            21.6            21.3  ...                  0.43
# ...

# %%
# Get the largest decrease changes in sat participation
final_add.nsmallest(5,'sat_trend')
# Out:
#           state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 9       Florida                  0.83          520          497          1017
# 28       Nevada                  0.26          563          553          1116
# 2       Arizona                  0.30          563          553          1116
# 6   Connecticut                  1.00          530          512          1042
# 7      Delaware                  1.00          503          492           995
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 9                   0.73            19.0         19.4            21.0
# 28                  1.00            16.3         18.0            18.1
# 2                   0.62            18.6         19.8            20.1
# 6                   0.31            25.5         24.6            25.6
# 7                   0.18            24.1         23.4            24.8
#
#     act_17_science  ...  act_18_participation  act_18_composite  \
# ...

# %%
final_add[['state','sat_trend']].sort_values('sat_trend').head()
# Out:
#        state  sat_trend
# 9    Florida      -0.27
# 28    Nevada      -0.03
# 2    Arizona      -0.01
# 16    Kansas       0.00
# 22  Michigan       0.00

# %%
# Create 2 new columns for the difference in SAT and ACT participation rates
final_add['sat_act_part_diff_17'] = final_add['sat_17_participation'] - final_add['act_17_participation']
final_add['sat_act_part_diff_18'] = final_add['sat_18_participation'] - final_add['act_18_participation']
final_add.head()
# Out:
#         state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 0     Alabama                  0.05          593          572          1165
# 1      Alaska                  0.38          547          533          1080
# 2     Arizona                  0.30          563          553          1116
# 3    Arkansas                  0.03          614          594          1208
# 4  California                  0.53          531          524          1055
#
#    act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 0                  1.00            18.9         18.4            19.7
# 1                  0.65            18.7         19.8            20.4
# 2                  0.62            18.6         19.8            20.1
# 3                  1.00            18.9         19.0            19.7
# 4                  0.31            22.5         22.7            23.1
#
#    act_17_science  ...  act_18_participation  act_18_composite  \
# ...

# %%
# Find states where difference between SAT and ACT participation in 2017 is within 10%
diff17_10= final_add[(final_add['sat_act_part_diff_17'] >= -.1) & (final_add['sat_act_part_diff_17'] <= .1)]
diff17_10
# Out:
#       state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 9   Florida                  0.83          520          497          1017
# 10  Georgia                  0.61          535          515          1050
# 37   Oregon                  0.43          560          548          1108
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 9                   0.73            19.0         19.4            21.0
# 10                  0.55            21.0         20.9            22.0
# 37                  0.40            21.2         21.5            22.4
#
#     act_17_science  ...  act_18_participation  act_18_composite  \
# 9             19.4  ...                  0.66              19.9
# 10            21.3  ...                  0.53              21.4
# 37            21.7  ...                  0.42              21.3
#
#     is_sat_required  is_act_required  region        division  \
# 9                No               No   South  South Atlantic
# ...

# %%
diff17_10[['state', 'sat_17_participation', 'act_17_participation','sat_act_part_diff_17','region','is_sat_required', 'is_act_required']]
# Out:
#       state  sat_17_participation  act_17_participation  sat_act_part_diff_17  \
# 9   Florida                  0.83                  0.73                  0.10
# 10  Georgia                  0.61                  0.55                  0.06
# 37   Oregon                  0.43                  0.40                  0.03
#
#    region is_sat_required is_act_required
# 9   South              No              No
# 10  South              No              No
# 37   West              No              No

# %% [markdown]
# These above 3 states are neither required to take SAT nor ACT, we can see they don't have much preference on which test to go. If SAT would contract with any of them, it might be easy to buy in as currently they have been participatd 40% above in SAT.

# %%
# Find states where difference between SAT and ACT participation in 2018 is within 10%
diff18_10=final_add[(final_add['sat_act_part_diff_18'] >= -.1) & (final_add['sat_act_part_diff_18'] <= .1)]
diff18_10
# Out:
#       state  sat_17_participation  sat_17_ebrw  sat_17_math  sat_17_total  \
# 1    Alaska                  0.38          547          533          1080
# 9   Florida                  0.83          520          497          1017
# 37   Oregon                  0.43          560          548          1108
#
#     act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 1                   0.65            18.7         19.8            20.4
# 9                   0.73            19.0         19.4            21.0
# 37                  0.40            21.2         21.5            22.4
#
#     act_17_science  ...  act_18_participation  act_18_composite  \
# 1             19.9  ...                  0.33              20.8
# 9             19.4  ...                  0.66              19.9
# 37            21.7  ...                  0.42              21.3
#
#     is_sat_required  is_act_required  region        division  \
# 1                No               No    West         Pacific
# ...

# %%
diff18_10[['state', 'sat_18_participation', 'act_18_participation','sat_act_part_diff_18','region','is_sat_required', 'is_act_required']]
# Out:
#       state  sat_18_participation  act_18_participation  sat_act_part_diff_18  \
# 1    Alaska                  0.43                  0.33                  0.10
# 9   Florida                  0.56                  0.66                 -0.10
# 37   Oregon                  0.48                  0.42                  0.06
#
#    region is_sat_required is_act_required
# 1    West              No              No
# 9   South              No              No
# 37   West              No              No

# %% [markdown]
# Compare the states in 2017 difference, Florida & Oregon remain a neutral position among SAT & ACT. We would consider some recommendations to win them towards SAT.

# %%
# Find states with > 50% participation on both tests in 2018
final_add[(final_add['sat_18_participation'] >= 0.50) & (final_add['act_18_participation'] >= 0.50)]
# Out:
#              state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 9          Florida                  0.83          520          497
# 10         Georgia                  0.61          535          515
# 11          Hawaii                  0.55          544          541
# 33  North Carolina                  0.49          546          535
# 40  South Carolina                  0.50          543          521
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 9           1017                  0.73            19.0         19.4
# 10          1050                  0.55            21.0         20.9
# 11          1085                  0.90            17.8         19.2
# 33          1081                  1.00            17.8         19.3
# 40          1064                  1.00            17.5         18.6
#
#     act_17_reading  act_17_science  ...  act_18_participation  \
# 9             21.0            19.4  ...                  0.66
# ...

# %% [markdown]
# From above data analyzing, We can have an initial conclude that more states are increasing the participation rate in SAT rather than ACT, also because of this, more states reduced the participation in ACT test.

# %% [markdown]
# ###  Summay of the EDA findings:
#
# ##### [Lowest Participation Rate] by Region-State
#
# - 2017 SAT-0.02 (3 states): Midwest(2 states)-Iowa,North Dakota,South-Mississippi，
# - 2018 SAT-0.02 (1 state): Midwest-North Dakota
# - 2017 ACT-0.08 (1 state): New England-Maine
# - 2018 ACT-0.07 (1 state): New England-Maine
#
# ##### [Highest Participation Rate] by Region-State
#
# - 2017 SAT-1 (3 states): Northeast-Connecticut, South-Delaware, Midwest-Michigan
# - 2018 SAT-1 (5 states): West(2 states)-Colorado, Idaho, Northeast-Connecticut, South-Delaware, Midwest-Michigan
# - 2017 ACT-1 (17 states):
#   - South(9 states)-Alabama,Arkansas,Kentucky,Louisiana,Mississippi,North Carolina,Oklahoma, South Carolina,Tennessee,
#   - West(5 states)-Colorado,-Montana,Nevada,Utah,Wyoming,
#   - Midwest(3 states)-Minnesota, Missouri, Wisconsin
# - 2018 ACT-1 (17 states):
#   - South(9 states)-Alabama,Arkansas,Kentucky,Louisiana,Mississippi,North Carolina,Oklahoma,South Carolina,Tennessee,
#   - West(6 states)-Colorado,Montana,Nevada,Utah,Wyoming,Nebraska, Midwest(4 states)-Ohio, Minnesota,Missouri,Wisconsin
#
# ##### [Highest Total/Composite Rate]
#
# - 2017 SAT-1295 (1 state): Midwest-Minnesota
# - 2018 SAT-1298 (1 state): Midwest-Minnesota
# - 2017 ACT-25.5 (1 state): New England-New Hampshire
# - 2018 ACT-25.6 (1 state): Northeast-Connecticut
#
# ##### [Lowest Total/Composite Rate]
#
# - 2017 SAT-950 (1 state): South-District of Columbia
# - 2018 SAT-977 (5 states):
#   - South(2 states)-District of Columbia,Delaware,
#   - South Atlantic-West Virginia,
#   - West(2 states)-Idaho,Utah
# - 2017 ACT-17.8 (5 states):
#   - South(3 states)-Mississippi,South Carolina,North Carolina,
#   - West(2 states)-Nevada,Hawaii
# - 2018 ACT-17.7(1 state): West-Nevada
#
# ##### [100% on a given test with rate of change year-to-year]
# - SAT drops:    South-District of Columbia
# - SAT increases: West(2 states)-Colorado, Idaho
# - ACT drops: West-Colorado, Midwest-Minnesota
# - ACT increases: West-Nebraska, Midwest-Ohio
#
# ##### [Above 50% participation on both tests either year]
# - 2017-3 states: South(2 states)-Florida,Georgia, West-Hawaii
# - 2018-5 states: South(5 states)-Florida, Georgia, Hawaii, South Carolina, North Carolina
#
# ##### [Year over Year increased]
#
# - SAT-33 states:
#   - South(13 states)-Alabama,Arkansas,District of Columbia,Georgia, Maryland，Mississippi，North Carolina，Oklahoma，South Carolina，Tennessee，Texas，Virginia，West Virginia
#   - West(9 states)-Alaska,California,Colorado,Hawaii,Idaho,New Mexico，Oregon，Utah，Washington，
#   - Northeast(7 states)-Maine，Massachusetts，New Jersey，New York, Pennsylvania，Rhode Island，Vermont
#   - Midwest(5 states)-Illinois,Iowa,Minnesota，Missouri，Ohio，
#
# - ACT-7 states:
#   - West（3 states)-Arizona，New Mexico，Oregon
#   - Midwest(3 states)-Iowa，Nebraska，Ohio
#   - South(1 states)-Maryland
#
# ##### [Year over Year decreased]
# - SAT-3 states:
#   - West(2 states): Arizona,Nevada
#   - South(1 state): Florida
#
# - ACT-26 states:
#   - West(6 states)-Alaska,California,Colorado,Hawaii,Idaho,Washington
#   - Northeast(9 states)-Connecticut, Massachusetts, Maine,New Hampshire, New Jersey,Pennsylvania,New York,Rhode Island,Vermont
#   - Midwest(6 states)-Illinois,Indiana,Kansas,Michigan,Minnesota,South Dakota
#   - South(5 states)-Virginia,West Virginia,Delaware,Florida,Georgia

# %% [markdown]
# ## Data Visualization
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# compute the correlation matrix
corr=final_add.corr()
corr
# Out:
#                       sat_17_participation  sat_17_ebrw  sat_17_math  \
# sat_17_participation              1.000000    -0.871288    -0.852002
# sat_17_ebrw                      -0.871288     1.000000     0.987056
# sat_17_math                      -0.852002     0.987056     1.000000
# sat_17_total                     -0.864294     0.996656     0.996860
# act_17_participation             -0.842892     0.716153     0.682572
# act_17_english                    0.684645    -0.461345    -0.420673
# act_17_math                       0.710409    -0.486126    -0.420456
# act_17_reading                    0.703718    -0.488441    -0.442410
# act_17_science                    0.652818    -0.422130    -0.365515
# act_17_composite                  0.693417    -0.470382    -0.417817
# sat_18_participation              0.875551    -0.818925    -0.789166
# sat_18_ebrw                      -0.664284     0.814096     0.800380
# sat_18_math                      -0.684000     0.865909     0.878982
# ...

# %%
sns.set_theme(style="white")

# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))

# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(corr, mask=mask,vmin=-1, vmax=1, annot=True, cmap=cmap)

# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('SAT & ACT Triangle Correlation Heatmap', fontdict={'fontsize':16}, pad=12);

# %%
# pairplots to visualize which feature has a stronger or weaker correlation/linear related to SAT participation
sns.pairplot(final_add)

# %%
# take a closer look at the all features correlation with sat_2017_participation & sat_2018_participation

plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(corr[['sat_17_participation']].sort_values(by='sat_17_participation', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with sat_17_participation', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(corr[['sat_18_participation']].sort_values(by='sat_18_participation', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with sat_18_participation', fontdict={'fontsize':18}, pad=16);

# %%
# take a closer look at the all features correlation with act_2017_participation & act_2018_participation

plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(corr[['act_17_participation']].sort_values(by='act_17_participation', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with act_17_participation', fontdict={'fontsize':18}, pad=16);

# %%
# take a closer look at the all features correlation with act_2017_participation & act_2018_participation

plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(corr[['act_18_participation']].sort_values(by='act_18_participation', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with act_18_participation', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# I can observe a few significant correlations from above 5 heatmaps:
#
# - ACT 2017 participation and SAT 2017 participation are strong negatively correlated (-0.84). Possible reason could be states that participated in one test tends to forgo another. Similarly in 2018 as well (-0.87).
# - SAT 2017 participation and SAT 2018 participation are strong positively correlated (0.87). States who participate in SAT 2017 tends to participate in 2018 as well. Similary for ACT test, states who take part in ACT in 2017 will also likely take part in 2018 (0.92).
# - ACT 2017 subjects english, math, reading, science and composite generally negatively correlated to ACT 18 participation. Possible reason could be a drop in participation compared to 2017. On the other hand, ACT 2017 subjects have positve relationship with SAT 2018 participation. This could be because, states who participate in ACT 2017 are switching to SAT in 2018.
# - SAT 2018 participation and SAT 2018 subjects ebrw (-0.76), math(-0.79), total(-0.79) are generally negatively correlated. This means higher participation leads to lower score, vice versa, lower participation leads to higher score.
#
# Reference:
# - https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
# define a function to add & create subplots for SAT & ACT 2017-2018 participation rate histograms
def subplot_histograms(dataframe, list_of_columns, list_of_titles, ylabel, xlabel, figtitle, figsize):

    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize= figsize)   # You'll want to specify your figsize
    
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
        
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],color="turquoise")
    
    # Set titles, labels, etc here for each subplot
    
    for i, title in enumerate(list_of_titles):
        ax[i].set_title(title, fontsize=14)
        ax[i].set_ylabel(ylabel, fontsize=12)
        ax[i].set_xlabel(xlabel, fontsize=12)
        ax[i].tick_params(axis='x', labelsize=14)
        ax[i].tick_params(axis='y',labelsize=14)
        
        fig.suptitle(figtitle, size=16)

# %%
participate_col = ['sat_17_participation', 
                   'act_17_participation', 
                   'sat_18_participation', 
                   'act_18_participation']

titles = ['SAT 2017 Participation Distribution',
         'ACT 2017 Participation Distribution',
         'SAT 2018 Participation Distribution',
         'ACT 2018 Participation Distribution']

# %%
subplot_histograms(final_add,
                   participate_col,
                   titles,
                   'No. of States',
                   'Participation Rate',
                   'SAT & ACT Year 2017-18 Participation Rate',
                   (25,25))

# %%
# Histograms of increase/decrease trend in SAT & ACT participation 2017-2018 
# if sat_trend >0, means SAT participation rate increase year over year. Otherwise, decreased or remained the same. 
# if act_trend >0, means ACT participation rate increase year over year. Otherwise, decreased or remained the same.

trend_col = ['sat_trend', 
             'act_trend']

titles_trend = ['Change in SAT Participation',
               'Change in ACT Participation']

subplot_histograms(final_add,
                   trend_col,
                   titles_trend,
                   'No. of States',
                   '2018 - 2017 Participation',
                   'Change in SAT/ACt Participation from 2017 to 2018',
                   (20, 9))

# %%
# Histograms of total scores for SAT from 2017-2018

score_col = ['sat_17_total', 
             'sat_18_total']

titles_score = ['SAT Total Score 2017',
                'SAT Total Score 2018']

subplot_histograms(final_add,
                   score_col,
                   titles_score,
                   'No. of States',
                   'Total Score',
                   'SAT Total Score 2017-2018',
                   (12, 5))

# %%
# Histograms of mean composition scores for ACT from 2017-2018

score_col = ['act_17_composite', 
             'act_18_composite']

titles_score = ['ACT Mean Composition Score 2017',
                'ACT Mean Composition Score 2017']

subplot_histograms(final_add,
                   score_col,
                   titles_score,
                   'No. of States',
                   'Composition',
                   'ACT Mean Composition Score 2017-2018',
                   (12, 5))

# %% [markdown]
# Histograms represent the frequency that numeric data values appear within a specified range within a dataset (e.g. how many values in the data fall within the range of 40%-50%). Below are some observations from histograms:
#
#
# SAT Participation vs ACT Participation
# - There are more States with 90%–100% participation rates for the ACT in 2017 and 2018. Conversely, there are more States with 0%-10% participation rates for the SAT in 2017 and 2018. We can infer that higher frequency of States with 90%-100% ACT participation rates could be caused by some regulation that requires taking the ACT.
#
# SAT 2017 vs SAT 2018
# - The number of states that had participation rate lower than 10% decreased from 21 states in 2017 to 18 states in 2018. Participation rate over 90% increased from 7 in 2017 to 10 in 2018. Generally, participation rate for SAT increases from 2017 to 2018.
#
# ACT 2017 vs ACT 2018
# - Generally, the participation rate drops from 2017 to 2018. The number of states with over 90% participation rate remain at 18 states in 2017 and 2018. However, the number of states with participation rate lower than 10% increased from 2017 to 2018. Besides that, the general shape of the histogram had shifted more towards the left, indicating a lower particiaption rate.
#
# SAT Total Score
# - The total score has overall increased as the average total score
#
#
# Reference:
# - https://seaborn.pydata.org/tutorial/axis_grids.html
# - https://matplotlib.org/2.0.2/users/pyplot_tutorial.html

# %% [markdown]
# "We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data."

# %% [markdown]
# [Answer]:
#
# For SAT & ACT 2017-2018 Participation Rate histograms,We have concluded that because of selection bias in state-by-state test participation the score probability distributions are unlikely to follow a Normal. Therefore, any state-level estimates relying on an assumption of normality can not be relied upon.

# %% [markdown]
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels

# %%
#Boxplot for ACT and SAT participation rates, 2017 and 2018 (4 vars)
participation_rates = final_add.loc[:,['sat_17_participation','sat_18_participation','act_17_participation','act_18_participation']]
participation_rates = participation_rates.rename(columns={
    'sat_17_participation':'SAT 2017',
    'sat_18_participation':'SAT 2018',
    'act_17_participation':'ACT 2017',
    'act_18_participation':'ACT 2018'
})
plt.figure(figsize=(10,6))
plt.title('The Distribution of State ACT and SAT Participation Rates, 2017-18')
sns.boxplot(data=participation_rates,orient='h',palette='Set2');

# %% [markdown]
# As We can see in box plots above it clearly visualized, first impression is that ACT is the winner, as the distribution of ACT participation rate accross 51 states is centered significantly higher than that of the SAT. Let's compare the plot one by one and see what the details box plot could tell us:
#
# Comparing SAT 2017 vs 2018 Paricipation Rate
# - There was a drastic increase in participation rate from 2017 to 2018. The median increased from 0.38 in 2017 to 0.52 in 2018. Q3 also increased from 0.66 in 2017 to 0.775 in 2018.
#
# Comparing ACT 2017 vs 2018 Paricipation Rate
# - There was a drop in participation from 2017 to 2018. The median decreased from 0.69 in 2017 to 0.66 in 2018, it infers a decreasing trend of participations for ACT exam. Q3 in 2018 also droped down to 0.285 from 2017's 0.31.
#
# Comparing 2017 SAT vs ACT Participation Rate
# - ACT has a higher median of 0.69 compared to 0.38 of SAT. Quarter 1(Q1)of SAT was 0.04 compared to 0.31 for ACT. Q3 for SAT was 0.66 compared to 1.0 for ACT. SAT minimum and maximum were 0.02 and 1 respectively. ACT minimum and maximum were 0.08 and 1 respectively. ACT has a higher participation rate compared to SAT in 2017.
#
# Comparing 2018 SAT vs ACT Participation
# - ACT still has higher participation compared to SAT. The median of ACT was 0.66 while SAT was 0.52. ACT also has a higher Q3 and Q1 which was 1 and 0.285 respectively. While SAT Q3 and Q1 were lower which was 0.775 and 0.045 respectively.

# %%
#Boxplot for ACT and SAT participation rates, 2017 and 2018 (4 vars)
participation_rates = final_add.loc[:,['sat_act_part_diff_17','sat_act_part_diff_18','sat_trend','act_trend']]
participation_rates = participation_rates.rename(columns={
    'sat_act_part_diff_17':'2017 SAT-ACT Participation Difference',
    'sat_act_part_diff_18':'2018 SAT-ACT Participation Difference',
    'sat_trend':'2017-2018 SAT Participation Difference ',
    'act_trend':'2017-2018 ACT Participation Difference'
})
plt.figure(figsize=(10,6))
plt.title('The Distribution of State ACT and SAT Participation Rates, 2017-18')
sns.boxplot(data=participation_rates,orient='h',palette='Set2');

# %% [markdown]
# From above box plot We could infer that a higher participation difference in year 2018 than 2017 between SAT and ACT (from "2018 SAT-ACT Participation Difference" plot, also We can see that the higher increases SAT participation rate in box plot of "2017-2018 SAT Participation Different".
#
# This finding is matching with what We have observed during EDA Analysis, that 33 states increased their participation rate in SAT exam, while only 7 states increased in ACT exam.
#
# Same as what We have researched, this increasing result is highly influenced by the states policies and exam structure changes in year 2017 & 2018.

# %% [markdown]
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable

# %%
#Defines a function to create a scatterplot between two variables
def create_scatterplot(title,x,y,xlabel=None,ylabel=None,regplot=False,lineplot=False):
    
    if xlabel == None:
        xlabel = x.name
    if ylabel == None:
        ylabel = y.name
        
    plt.figure(figsize=(8,8))
        
    if regplot:
        sns.regplot(x=x,y=y)
    else:
        sns.scatterplot(x=x,y=y)
        
    if lineplot == True:    
        
        diff_x = max(x) - min(x)        
        if diff_x > 36:
            sf = 50
        else:
            sf = 1   
        
        min_x = np.floor((min(x)*0.95)/sf) * sf
        max_x = np.ceil((max(x)*1.05)/sf) * sf      
        
        X_plot = np.linspace(min_x, max_x, 100)
        Y_plot = X_plot    
        plt.plot(X_plot, Y_plot, color='salmon',linestyle='dashed')
        plt.xlim(min_x,max_x)
        plt.ylim(min_x,max_x)
                    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
x = final_add['act_18_participation']
y = final_add['act_18_composite']
title = ("2018-ACT Participation Varies Inversely With Mean ACT Composite Score")

create_scatterplot(title,x,y)

# %% [markdown]
# The scatterplots clearly demonstrate the relationship between participation rate and test scoring, the lower rates of participation correspond with higher mean score by state. Let's also take a look for SAT exam.

# %%
x = final_add['sat_18_participation']
y = final_add['sat_18_total']
title = ("2018-SAT Participation Varies Inversely With Mean Total SAT Score")

create_scatterplot(title,x,y)

# %% [markdown]
# For SAT, there's a surge participation rate in 2018 from our above findings conclusion, however, the scatterplot clearly shows lower rates of participation correspond with higher mean score by state.
# After research, that is due to the SAT is scored on a curve. If the mathematics exam is unusually easy, students will on average get more questions correct than in a typical SAT administration. But the College Board then compensates with a curve, and missing a relatively small number of questions can result in a much lower score than would typically be the case.
#
# Reference:
# - https://www.insidehighered.com/admissions/article/2018/07/12/surprisingly-low-scores-mathematics-sat-stun-and-anger-students

# %%
#SAT vs. ACT math participation for 2017

x = final_add['sat_17_participation']
y = final_add['act_17_participation']
title = ("SAT vs. ACT participation for 2017")
         
create_scatterplot(title,x,y,regplot=True)

# %% [markdown]
# From above Scatter plot, We could see SAT participation rate has a strongly negative relationship with ACT participation rate. This suggests that states with higher SAT participation rate tend to have lower ACT participation rate and vice versa.

# %%
#SAT vs. ACT math participation for 2017

x = final_add['sat_17_participation']
y = final_add['sat_18_participation']
title = ("SAT participation for 2017 vs 2018")
         
create_scatterplot(title,x,y,regplot=True)

# %% [markdown]
# From above Scatter plot, We could see SAT participation rate in 2017 has a strongly positive relationship with the participation rate in 2018. This suggests high school students in most states likely to refer to the last or past years particiation exam to take.

# %% [markdown]
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Let us take a look at the states with most college students population according to American School and University. We will focus on top 10 ranked states.
#
# Reference:
# * https://www.asumag.com/research/top-10s/article/20856007/states-with-most-college-students-as-a-percentage-of-population
# * https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/

# %%
#plot a bar chart sort by the sat_trend decreasing to check from the most highest increasing states to the least increasing
# for top 10 ranked most college students population states
states_lit_pop=['New Hampshire', 
                'Washington D.C.', 
                'Utah',
                'West Virginia', 
                'North Dakota', 
                'Kansas',
                'Nebraska',
                'Rhode Island',
                'Minnesota',
                'Massachusetts']

df = final_add[final_add['state'].isin(states_lit_pop)]
df_plot = df[['state','sat_17_participation','sat_18_participation','sat_trend']]
df_plot = df_plot.sort_values(by=['sat_trend'])

ax= df_plot.plot(x='state', 
            y=['sat_17_participation','sat_18_participation'], 
            kind='barh', 
            color={"sat_17_participation": "red", "sat_18_participation": "green"},
            figsize=(20,30)) 

ax.set_title("SAT Participation 2017 vs 2018 by increasing trend", fontsize=18)
ax.set_xlabel("Participation Rate", labelpad=20, weight='bold', size=12)
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)
# Out:
# Text(0, 0.5, 'State')

# %%
final_add[(final_add['sat_18_participation'] > 0.5) & (final_add['act_18_participation'] > 0.5)]

# %%
df[(df['is_sat_required'] == 'No') & (df['is_act_required'] == 'No')]
# Out:
#             state  sat_17_participation  sat_17_ebrw  sat_17_math  \
# 16         Kansas                  0.04          632          628
# 21  Massachusetts                  0.76          555          551
# 23      Minnesota                  0.03          644          651
#
#     sat_17_total  act_17_participation  act_17_english  act_17_math  \
# 16          1260                  0.73            21.1         21.3
# 21          1106                  0.29            25.4         25.3
# 23          1295                  1.00            20.4         21.5
#
#     act_17_reading  act_17_science  ...  act_18_participation  \
# 16            22.3            21.7  ...                  0.71
# 21            25.9            24.7  ...                  0.25
# 23            21.8            21.6  ...                  0.99
#
#     act_18_composite  is_sat_required  is_act_required     region  \
# 16              21.6               No               No    Midwest
# ...

# %% [markdown]
# Above 3 states located Midwest region Kansas & Minnesota, and at Northeast region the Massachusetts, they are states sitting on the fence, they do not favour either SAT or ACT.

# %% [markdown]
# I also plotted the participation rate map in Tableau and published on Tableau Publich for a better and direct visualization.
# * https://public.tableau.com/profile/nola2967#!/vizhome/US_SAT_ACT_2017_2018ParticipationRatebyStates/2018ACT
# * https://public.tableau.com/profile/nola2967#!/vizhome/2017ACTMeanParticipationRate/2017ACT?publish=yes
# * https://public.tableau.com/profile/nola2967#!/vizhome/2017SATMeanParticipationRate/2017SAT?publish=yes
# * https://public.tableau.com/profile/nola2967#!/vizhome/2018SATMeanParticipationRate/2018SAT?publish=yes
#
# To better visualize which states have required to take SAT or ACT exam, I added Happy Face emoji 😃 to show those states are required to take SAT exam, while Sad Face emoji 😔 to show those states required to take ACT exam, •✧✧• to display on states are either SAT or ACT.
#
# We can see that ACT is more popular in the Midwestern, West, and South regions in United States, while the SAT predominates on the Northeast and West Coasts states. In 2018, SAT has increased more Happy Faces 😃 on the map and won 2 significant states Colorado in West region (which is neighbor to Midwest region) and Illinois state in Midwest region.

# %%
path = '../images/'
Image(filename = path + "2017 SAT Mean Participation Rate by States.jpg")

# %%
Image(filename = path + "2018 SAT Mean Participation Rate by States.jpg")

# %%
Image(filename = path + "2017 ACT Mean Participation Rate by States.jpg")

# %%
Image(filename = path + "2018 ACT Mean Participation Rate by States.jpg")

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# The 3 states located Midwest region Kansas & Minnesota, and at Northeast region the Massachusetts state are chosen to provide suggestions by College Board. According to American School and University, Kansas was ranked top 6 in student to population ratio, Minnesota was ranked top 9 and Massachusetts at top 10. It would be a great boost if SAT can win them over. Moreover, they are states sitting on the fence, they do not favour either SAT or ACT.
#
# My suggestions based on the marketing 4ps are as follows:
#
# * Price:
#    - Provide free test preparation materials and review lessons by partnering up with study platforms (eg. Khan academy)
#    - Lower the entry barrier for low-income students by offering testing fee waivers
#
# Our strategy for SAT is to increase participatin rate, however from one of above scatter plots there's a strong negative correlation between participation rate and total score. But when doing the research, We also found an interesting part that rich students got better score in the SAT test.One reason wealthier students get higher SAT scores is because they can afford to take the test several times, which has been known to increase a students’ score.
#
# The cost to take the SAT during the 2018-2019 school year was about 47.5USD for the basic test and 64.50USD to take the test with the full essay section. To take an SAT subject test, students must pay a 26USD registration fee, 22USD for each additional test and 26USD for each language test.These costs can be prohibitively expensive for many students.
#
# The College Board can try to increase SAT participation through fee waivers for low-income students, and by taking steps to identify eligible students and automatically giving them the fee waiver benefits. Also by parternership with study platforms, e.g. Khan Academy students is able to get free test preparation materials and review lessons to help get more familiar with the test, build up their confidence and work on a higher test score eventually.
#
# * Product:
#    - Improve testing convenience by allowing remote arrangements to be made.
#    - Allow exam candidates to reschedule their examination date
#
# Due to Covid 19, US Nationwide, more than 1,550 colleges have made the test optional for admissions, increasing about 50% since 2020, that's about two-thirds of all colleges nationwide according to Akil Bello of the National Organization for Fair and Open Testing. Many schools decided either just before or right after the start of the coronavirus pandemic, said Bello, who is senior director of advocacy and advancement. This is a big challenge to College Board.
#
# In this current unprecedented time, how College Board could provide the most oppotunity for the greatest number of students is one of our key considerations, We want to ensure that all students have the best opportunity to persue higher education. Also We know that many students have had difficulty taking a standadized test due to cancellations. By revising the policies and giving the options to select for remote test arrangement, also allowing students to reschedule their examination date, these actions allow for more flexibility and eliminate a potential barrier.
#
# * Place:
#    - Target states with bigger college students population and also which have not made the SAT a mandatory high school graduation requirement (Kansas, Minnesota & Massachusetts)
#    - To collaborate with school districts on offering more SAT School Days.
#
# Gerneally our target are states which have not made the SAT a mandatory hight school graduation requirement, and we sugguest to work focus on the prompt SAT exam for the 3 states-Kansas, Minnesota & Massachusetts, as they have higher student populations. It would be a big success and contribute to our revenue a lot if we could win them over.
#
# The College Board can try to cllaborate with school districts on offering more SAT School Days. By breaking down barries to access, SAT School Days can have a profound impact, it generally includes a free SAT exam offered during the school
# day to make student participation as convenient as possible.
#
# Again, We talk about the convience, students don't have to worry about locating or getting to the testing site, School Days testing also won't disrupt weekend plans, jobs or family time. School Days also improve the comfortability for students to take the test in familiar surroundings with people & place they know. Giving students an equal platform to score better well would be a better strategy than only looking at how to increase the participation rate.
#
# * Promotion:
#    - Team up with the states' education leaders to roll out college‐ and career‐readiness initiatives so that the students are more encouraged to think about their future
#    - Provide college entry assistance to students who take the SAT exam.
#
# College Board can team up with the states' education leaders to roll out college-and career-readiness initiatives so that the students are more encouraged to think abou their future. For instance, transforming the notion that "attending college is an option" to "attending college is an expectation", indirectly leads to the desire to succeed and a drive to attend college. Understanding students' opinions and knowledge about college, as well as their vision for the future will help to
# establish a culture of college and career readiness, utimately increase SAT preparation and participation.

# %% [markdown]
# ## Future Work & Data Collection Considerations

# %% [markdown]
# There are other data We could explore further in future analysis and improvement:
#
# 1. The population, race and geographic data for each state in the test taken year. Some states may face aging problem, or with low income might contribute to low or high participation rate on the test, or different race might have preference towards one tet (SAT or ACT).
# 2. The types of schools (private or public) that participated in SAT or ACT, this might show some trends on participation rate and average score.
# 3. High school students family income, to analyze if there's any correlation the higher partication rate with certain groups of family income. This could help us to target on the students family group and provide any free test/test fee waiver to other family income groups.
# 4. Parents education background--there's a possible pattern we could find if with this data, that higher educated parents have a higher influence on their children to achieve a higher test score.

# %% [markdown]
# ## Reference:
# - https://www.insidehighered.com/admissions/article/2018/10/29/sat-scores-are-gaps-remain-significant-among-racial-and-ethnic-groups
# - https://www.testive.com/colorado-sat-change-2017/
# - https://newsroom.collegeboard.org/more-2-million-students-class-2018-took-sat-highest-ever
# - https://chicago.chalkbeat.org/2018/7/27/21105418/illinois-has-embraced-the-sat-and-the-act-is-mad-about-it
# - https://www.orlandosentinel.com/news/education/os-ne-act-sat-florida-scores-20181024-story.html
# - https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html
# - https://collegereadiness.collegeboard.org/pdf/sat-propelling-college-going-in-maine.pdf
# - https://www.idahoednews.org/state-board-of-education/state-board-waives-college-entrance-exam-requirement-for-class-of-2021/
# - https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html
# - https://collegereadiness.collegeboard.org/pdf/fall-2020-flexible-testing-options-guide-sat-suite.pdf
